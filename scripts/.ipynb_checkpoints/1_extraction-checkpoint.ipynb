# %% [markdown]
# # Requirements

# %%
import json
import re
import pandas as pd
import nltk
pd.options.display.max_columns = 1000 # to see all columns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Loading datasets

# %%
EDH = pd.read_json("../data/large_files/EDH_filtered.json")
EDH.head(5)
# Out:
#   responsible_individual    type_of_inscription letter_size  not_after  \
# 0                Feraudi                epitaph    3.2-2 cm      130.0
# 1                Feraudi                epitaph        4 cm      200.0
# 2                Feraudi  honorific inscription    4.5-3 cm      170.0
# 3                   Gräf     votive inscription      2.5 cm      200.0
# 4                Feraudi                epitaph        None      200.0
#
#                                           literature         work_status  \
# 0  AE 1983, 0192.; M. Annecchino, Puteoli 4/5, 19...         provisional
# 1  AE 1983, 0080. (A); A. Ferrua, RAL 36, 1981, 1...            no image
# 2  AE 1983, 0518. (B); J. González, ZPE 52, 1983,...         provisional
# 3  AE 1983, 0533. (B); A.U. Stylow, Gerión 1, 198...  checked with photo
# 4  AE 1983, 0078. (B); A. Ferrua, RAL 36, 1981, 1...            no image
#
#     height                                    diplomatic_text  \
# ...

# %%
EDCS = pd.read_json("../data/large_files/EDCS_filtered.json")

# %% [markdown]
# # Function to extract occupations

# %%
deities_csv = pd.read_csv("../data/deities_decline.csv").reset_index()
deities_csv
# Out:
#                        index               nom_sg              gen_sg  \
# 0                  Asclepius             Asclepii            Asclepio
# 1                Aesculapius           Aesculapii          Aesculapio
# 2                 Esculapius            Esculapii           Esculapio
# 3                  Asclepios             Asclepii            Asclepio
# 4                     Apollo            Apollonis            Apolloni
# 5                    Apollon            Apollonis            Apolloni
# 6                     Apolon             Apolonis             Apoloni
# 7                     Apolin             Apolinis             Apolini
# 8                    Apollin            Apollinis            Apollini
# 9    Iupiter Optimus Maximus  Iovis Optimi Maximi  Iovi Optimo Maximo
# 10  Iuppiter Optimus Maximus  Iovis Optimi Maximi  Iovi Optimo Maximo
# 11   Jupiter Optimus Maximus  Iovis Optimi Maximi  Iovi Optimo Maximo
# ...

# %%
deities_dict = {}

asclep = []
for n in range(4):
    asclep.extend([el for el in deities_csv.loc[n].tolist() if isinstance(el, str)])
deities_dict["asclep"] = list(set(asclep))

apollo = []
for n in range(4,9):
    apollo.extend([el for el in deities_csv.loc[n].tolist() if isinstance(el, str)])
deities_dict["apollo"] = list(set(apollo))

jupiter = []
for n in range(9,13):
    jupiter.extend([el for el in deities_csv.loc[n].tolist() if isinstance(el, str)])
deities_dict["jupiter"] = list(set(jupiter))

# %%
deities_dict["apollo"]
# Out:
# ['Apollonis',
#  'Apollini',
#  'Apolin',
#  'Apolini',
#  'Apolonem',
#  'Apolon',
#  'Apolline',
#  'Apolonis',
#  'Apollonem',
#  'Apollinem',
#  'Apollin',
#  'Apoloni',
#  'Apollo',
#  'Apolone',
#  'Apoline',
#  'Apollinis',
#  'Apolinem',
#  'Apolinis',
#  'Apollone',
#  'Apollon',
#  'Apolloni']

# %%
def test_extract(text):
    try:
        if re.search("(\W|^)Apollini(\W|$)", text):
            return True
        else:
            return False
    except:
        return False
len(EDH[EDH["clean_text_interpretive_word"].apply(test_extract)])
# Out:
# 258

# %%
def extract_deity(inscription_text, deity):
    if not isinstance(inscription_text, str): # if not valid string
        inscription_text = ""
    to_return = False
    for deity_morph in deities_dict[deity]:
        if deity_morph in inscription_text: # first check it this way, otherwise skip
            if re.search("(\W|^)" + deity_morph + "(\W|$)", inscription_text):
                to_return = True
                break
    return to_return

# %%
EDH["asclepius"] = EDH["clean_text_interpretive_word"].apply(extract_deity, deity="asclep")
EDH["apollo"] = EDH["clean_text_interpretive_word"].apply(extract_deity, deity="apollo")
EDH["jupiter"] = EDH["clean_text_interpretive_word"].apply(extract_deity, deity="jupiter")

# %%
print(len(EDH[EDH["asclepius"]]))
print(len(EDH[EDH["apollo"]]))
print(len(EDH[EDH["jupiter"]]))
# Out:
# 156
# 306
# 2598

# %%
EDCS["asclepius"] = EDCS["clean_text_interpretive_word"].apply(extract_deity, deity="asclep")
EDCS["apollo"] = EDCS["clean_text_interpretive_word"].apply(extract_deity, deity="apollo")
EDCS["jupiter"] = EDCS["clean_text_interpretive_word"].apply(extract_deity, deity="jupiter")

# %%
print(len(EDCS[EDCS["asclepius"]]))
print(len(EDCS[EDCS["apollo"]]))
print(len(EDCS[EDCS["jupiter"]]))
# Out:
# 90
# 205
# 391

# %%
EDH.to_json("../data/large_files/EDH_deities.json")
EDCS.to_json("../data/large_files/EDCS_deities.json")
